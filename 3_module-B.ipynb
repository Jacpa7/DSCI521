# %% [markdown]
# # Assignment group 3: Probabilistic modeling and prediction

# %% [markdown]
# #### Kiana Montazeri

# %% [markdown]
# ## Module B _(39 pts)_ Exploring conditional probability and prediction
# In This section we're going to experiment with some recipes data again, which can be obtained from Kaggle:
#
# - https://www.kaggle.com/kaggle/recipe-ingredients-dataset
#
# As usual, they're also in the assignment's directory:
#
# - `./data/train.json`

# %%
#Libraries in use:
from pprint import pprint
from collections import Counter
from collections import defaultdict
import json

# %% [markdown]
# __B1.__ _(3 pts)_ To start, load the json data and call the resulting object `recipes`.

# %%
with open('data/train.json', 'r') as f:
    recipes = json.load(f)
pprint(recipes[:2])
print(len(recipes))
#it is a list of dictionaries with cuisines names, ids and ingredients and it has 39774 recipes"
# Out:
# [{'cuisine': 'greek',
#   'id': 10259,
#   'ingredients': ['romaine lettuce',
#                   'black olives',
#                   'grape tomatoes',
#                   'garlic',
#                   'pepper',
#                   'purple onion',
#                   'seasoning',
#                   'garbanzo beans',
#                   'feta cheese crumbles']},
#  {'cuisine': 'southern_us',
#   'id': 25693,
#   'ingredients': ['plain flour',
#                   'ground pepper',
#                   'salt',
#                   'tomatoes',
#                   'ground black pepper',
#                   'thyme',
#                   'eggs',
#                   'green tomatoes',
#                   'yellow corn meal',
#                   'milk',
#                   'vegetable oil']}]
# 39774

# %% [markdown]
# __B2.__ _(2 pts)_ Instead of builing out these data as a network represented by an adjacency matrix, we'll still benefit from the latent network structure, instead storing it as an adjacency list. In particular, symmetrically store the number of shared recipes between pairs of ingredients:
#
# - ```
#     {
#         Ingredient: {
#             CoIngredient: NumSharedRecipes
#         }
#     }
# ```
#
# To do this, use a default dictionary of counters:
#
# - `defaultdict(lambda : Counter())`
#
# for the co-ingredient data.
#
# Note: you are only responsible for initializing the data structure in this part.

# %%
CUISINE = list(list(recipe['ingredients']) for recipe in recipes) ##only ingredients of the recipes
###################################
#make a set of all the ingredients:
ingredients = set() #define a set to avoid duplicates
for eachCUISINE in CUISINE:
    for eachelement in eachCUISINE:
        ingredients.add(eachelement)
###################################

# %%
CoIngredients = defaultdict(lambda : Counter())

# %% [markdown]
# __B3.__ _(5 pts)_ Now, count up the co-ingredient frequencies between all pairs of ingredients.

# %%
for each_ing in ingredients:
    counts = Counter()
    for recipe in CUISINE:
        if each_ing in recipe:
            for co_ing in recipe:
                if co_ing != each_ing:
                    counts[co_ing] += 1
    CoIngredients[each_ing] = counts

# %%
pprint(CoIngredients['pesto'])
# Out:
# Counter({'salt': 47,
#          'olive oil': 37,
#          'grated parmesan cheese': 30,
#          'pepper': 22,
#          'garlic': 17,
#          'ground black pepper': 16,
#          'onions': 16,
#          'zucchini': 14,
#          'mozzarella cheese': 14,
#          'water': 11,
#          'tomatoes': 10,
#          'extra-virgin olive oil': 10,
#          'black pepper': 10,
#          'red bell pepper': 9,
#          'garlic cloves': 9,
#          'fresh basil': 9,
#          'parmesan cheese': 9,
#          'butter': 8,
#          'roasted red peppers': 8,
#          'goat cheese': 7,
#          'fresh lemon juice': 7,
#          'fresh basil leaves': 7,
#          'chees fresh mozzarella': 7,
#          'dry white wine': 7,
#          'ricotta cheese': 7,
#          'plum tomatoes': 6,
#          'part-skim mozzarella cheese': 6,
#          'sun-dried tomatoes': 6,
#          'minced garlic': 6,
#          'carrots': 6,
#          'green beans': 6,
#          'eggs': 6,
#          'kosher salt': 6,
#          'lasagna noodles': 6,
#          'penne pasta': 6,
#          'cooking spray': 6,
#          'spinach': 6,
#          'lemon': 5,
#          'pinenuts': 5,
#          'pizza doughs': 5,
#          'boneless skinless chicken breasts': 5,
#          'cracked black pepper': 5,
#          'parmigiano reggiano cheese': 5,
#          'cream cheese': 5,
#          'shredded mozzarella cheese': 5,
#          'fresh parsley': 4,
#          'all-purpose flour': 4,
#          'large shrimp': 4,
#          'flat leaf parsley': 4,
#          'provolone cheese': 4,
#          'spaghetti': 4,
#          'cherry tomatoes': 4,
#          'oil': 4,
#          'chicken breasts': 4,
#          'baguette': 4,
#          'freshly ground pepper': 4,
#          'tomato sauce': 4,
#          'chicken breast halves': 4,
#          'white wine': 3,
#          'pizza crust': 3,
#          'arugula': 3,
#          'heirloom tomatoes': 3,
#          'diced tomatoes': 3,
#          'purple onion': 3,
#          'russet potatoes': 3,
#          'sour cream': 3,
#          'cannellini beans': 3,
#          'arborio rice': 3,
#          'unsalted butter': 3,
#          'large garlic cloves': 3,
#          'eggplant': 3,
#          'baby spinach': 3,
#          'bow-tie pasta': 3,
#          'fresh parmesan cheese': 3,
#          'cheese tortellini': 3,
#          'heavy cream': 3,
#          'chopped walnuts': 3,
#          'celery': 3,
#          'cheese': 3,
#          'balsamic vinegar': 3,
#          'dried oregano': 3,
#          'large eggs': 3,
#          'herbs': 3,
#          'crushed red pepper': 3,
#          'chicken broth': 3,
#          'linguine': 3,
#          'part-skim ricotta cheese': 3,
#          'tomato basil sauce': 3,
#          'nonfat ricotta cheese': 3,
#          'pasta sauce': 3,
#          'panko': 2,
#          'vegetable oil cooking spray': 2,
#          'yellow onion': 2,
#          'yellow bell pepper': 2,
#          'fresh lime juice': 2,
#          'red wine vinegar': 2,
#          'orzo': 2,
#          'chopped onion': 2,
#          'leeks': 2,
#          'swiss chard': 2,
#          'cornmeal': 2,
#          'green olives': 2,
#          'fresh leav spinach': 2,
#          'red potato': 2,
#          'flour': 2,
#          'dry bread crumbs': 2,
#          'boneless chop pork': 2,
#          'low sodium chicken broth': 2,
#          'fettuccine pasta': 2,
#          'pizza sauce': 2,
#          'bread': 2,
#          'buttermilk': 2,
#          'sugar': 2,
#          'dijon mustard': 2,
#          'warm water': 2,
#          'artichoke hearts': 2,
#          'asparagus': 2,
#          'yellow squash': 2,
#          'boneless skinless chicken breast halves': 2,
#          'canned low sodium chicken broth': 2,
#          'tomato paste': 2,
#          'fresh spinach': 2,
#          'fresh green bean': 2,
#          'frozen peas': 2,
#          'parsley': 2,
#          'tortellini': 2,
#          'almonds': 2,
#          'basil': 2,
#          'fontina cheese': 2,
#          'vegetable oil': 2,
#          'gnocchi': 2,
#          'cooking oil': 2,
#          'feta cheese': 2,
#          'mushrooms': 2,
#          'ham': 2,
#          'refrigerated pizza dough': 2,
#          'pasta': 2,
#          'milk': 2,
#          'sliced carrots': 2,
#          'wonton wrappers': 2,
#          'lemon wedge': 2,
#          'grated lemon peel': 2,
#          'sliced mushrooms': 2,
#          'brown sugar': 2,
#          'hot water': 2,
#          'non-fat sour cream': 2,
#          'lemon juice': 2,
#          'fresh mozzarella': 2,
#          'grape tomatoes': 2,
#          'red pepper flakes': 2,
#          'marinara sauce': 2,
#          'salmon fillets': 1,
#          'whole wheat pasta': 1,
#          'lettuce': 1,
#          'sausages': 1,
#          'grilled chicken': 1,
#          'flatbread': 1,
#          'sauce': 1,
#          'shrimp': 1,
#          'yellow corn meal': 1,
#          'pancetta': 1,
#          'shredded cabbage': 1,
#          'italian seasoning': 1,
#          'chopped celery': 1,
#          'fat skimmed chicken broth': 1,
#          'yukon gold': 1,
#          'lima beans': 1,
#          'rolls': 1,
#          'loin pork roast': 1,
#          'artichok heart marin': 1,
#          'smoked turkey': 1,
#          'semolina flour': 1,
#          'low-fat sour cream': 1,
#          'almond flour': 1,
#          'meatballs': 1,
#          'low salt chicken broth': 1,
#          'celery ribs': 1,
#          'chicken': 1,
#          'prepared pasta sauce': 1,
#          'pecans': 1,
#          'pork tenderloin': 1,
#          'rapid rise yeast': 1,
#          'pecan halves': 1,
#          'biscuit mix': 1,
#          'white onion': 1,
#          'vegetable stock': 1,
#          'black olives': 1,
#          'salad dressing': 1,
#          'grated romano cheese': 1,
#          'alfredo sauce mix': 1,
#          'crushed garlic': 1,
#          'coarse salt': 1,
#          'summer squash': 1,
#          'romaine lettuce': 1,
#          'hot pepper sauce': 1,
#          'worcestershire sauce': 1,
#          'anchovy paste': 1,
#          'canola mayonnaise': 1,
#          'fat free yogurt': 1,
#          'low-fat mayonnaise': 1,
#          'romaine lettuce leaves': 1,
#          'diced celery': 1,
#          'cabbage': 1,
#          'sole fillet': 1,
#          'pinto beans': 1,
#          'boiling potatoes': 1,
#          'fava beans': 1,
#          'hot Italian sausages': 1,
#          'sharp cheddar cheese': 1,
#          'herb seasoning': 1,
#          'tuna steaks': 1,
#          'capers': 1,
#          'shallots': 1,
#          'panko breadcrumbs': 1,
#          'ground turkey': 1,
#          'diced onions': 1,
#          'vegetable broth': 1,
#          'frozen mixed vegetables': 1,
#          'whole wheat rigatoni': 1,
#          'shredded cheese': 1,
#          'kale': 1,
#          'levain bread': 1,
#          'roasting chickens': 1,
#          'catfish fillets': 1,
#          'lemon slices': 1,
#          'shredded zucchini': 1,
#          'parmigiano-reggiano cheese': 1,
#          'ricotta': 1,
#          'bone-in pork chops': 1,
#          'rosemary sprigs': 1,
#          'chives': 1,
#          'fillets': 1,
#          'cilantro sprigs': 1,
#          'fresh rosemary': 1,
#          'corn kernels': 1,
#          'peppercorns': 1,
#          'peas': 1,
#          'fresh thyme': 1,
#          'anise seed': 1,
#          'romano cheese': 1,
#          'triscuits': 1,
#          'crackers': 1,
#          'Philadelphia Light Cream Cheese': 1,
#          'edamame': 1,
#          'half & half': 1,
#          'boneless chicken breast': 1,
#          'pasta shells': 1,
#          'ground beef': 1,
#          'canned chopped tomatoes': 1,
#          'whole wheat penne': 1,
#          'roasted tomatoes': 1,
#          'baby broccoli': 1,
#          'italian sausage': 1,
#          'active dry yeast': 1,
#          'bell pepper': 1,
#          'pepperoni': 1,
#          'bread flour': 1,
#          'wheels': 1,
#          'toasted walnuts': 1,
#          'low-fat mozzarella cheese': 1,
#          'walnuts': 1,
#          'french bread': 1,
#          'thin pizza crust': 1,
#          'havarti cheese': 1,
#          'fat free less sodium chicken broth': 1,
#          'pastina': 1,
#          'chicken breast tenders': 1,
#          'linguini': 1,
#          'frozen spinach': 1,
#          'leg of lamb': 1,
#          'french baguette': 1,
#          'cornichons': 1,
#          'ranch dressing': 1,
#          'corn starch': 1,
#          'nonfat yogurt': 1,
#          'chopped cooked ham': 1,
#          '(    oz.) tomato sauce': 1,
#          'vermicelli': 1,
#          '(10 oz.) frozen chopped spinach': 1,
#          'large egg whites': 1,
#          'mayonaise': 1,
#          'cremini mushrooms': 1,
#          'light cream': 1,
#          'sausage links': 1,
#          'sugar pea': 1,
#          'paprika': 1,
#          'thyme sprigs': 1,
#          'cream cheese, soften': 1,
#          'Corn Flakes Cereal': 1,
#          'lasagna noodles, cooked and drained': 1,
#          'sweet onion': 1,
#          'collard greens': 1,
#          'golden raisins': 1,
#          'fat-free cottage cheese': 1,
#          'snow peas': 1,
#          'puff pastry': 1,
#          'tomato purée': 1,
#          'shredded cheddar cheese': 1,
#          'chopped fresh chives': 1,
#          'chopped cilantro fresh': 1,
#          'stir fry vegetable blend': 1,
#          'frozen green beans': 1,
#          'potatoes': 1,
#          'great northern beans': 1,
#          'whole peeled tomatoes': 1,
#          'frozen ravioli': 1,
#          'broccoli florets': 1,
#          'wheat': 1,
#          'pasta water': 1,
#          'asiago': 1,
#          'skim milk': 1,
#          'gemelli': 1,
#          'ground nutmeg': 1,
#          'Alfredo sauce': 1,
#          'green bell pepper': 1,
#          'scallops': 1,
#          'littleneck clams': 1,
#          'tagliatelle': 1,
#          'mussels': 1,
#          'butter lettuce': 1,
#          'bread ciabatta': 1,
#          'white sandwich bread': 1,
#          'meat': 1,
#          'crushed tomatoes': 1,
#          'ziti': 1,
#          'bay leaf': 1,
#          'frozen shelled edamame': 1,
#          'parmagiano reggiano': 1,
#          'frozen cheese ravioli': 1,
#          'green pepper': 1,
#          'prosciutto': 1,
#          'light mayonnaise': 1,
#          'fat free cream cheese': 1,
#          'banana peppers': 1,
#          'salami': 1,
#          'sliced black olives': 1,
#          'sun-dried tomatoes in oil': 1,
#          'prebaked pizza crusts': 1,
#          'plain yogurt': 1,
#          'boneless chicken skinless thigh': 1,
#          'chicken tenderloin': 1,
#          'red chili powder': 1,
#          'sea salt': 1,
#          'oregano': 1,
#          'rocket leaves': 1,
#          'crumbled goat cheese': 1,
#          'andouille chicken sausage': 1,
#          'cavatappi': 1,
#          'waxy potatoes': 1})

# %% [markdown]
# __B4.__ _(2 pts)_ In the response box below answer the following questions:
# - Why didn't we choose to construct an adjacency matrix from our co-ingredients data?
# - Why was this _adjacency list_ a more efficient choice for computing the co-ingredient frequencies?

# %% [markdown]
# <font color=blue>Since we do not care about the order of the data, array is not absolutely necessary. We can assume a specific order and make an array. In this case, seince we are usig numpy, and dealing with indexes and counters(int numbers), the process would be faster and more efficient. In our way, the name of each ingredient is preserved and can be used directly in our calculations.</font>

# %% [markdown]
# __B5.__ _(5 pts)_ Write a function that finds the probability that a recipe contains a specific ingredient:
#
# $$P(\text{a recipe contains ingredient } A)$$
#
# This should be computed as:
#
# $$\frac{\text{number of times ingredient }A\text{ is used in any recipe}}{\text{number of recipes in the dataset}}$$
#
# When complete, exhibit that this function works by finding the probability that a recipe contains `"feta cheese"`.

# %%
def prob_recipes_one(ingredient, CUISINE):
    ing_used = [True for rec in CUISINE if ingredient in rec]
    probability = sum(ing_used)/len(CUISINE)
    return probability

# %%
fetaCheese_P = prob_recipes_one("feta cheese", CUISINE)

# %%
fetaCheese_P
# Out:
# 0.0067380700960426405

# %% [markdown]
# __B6.__ _(5 pts)_ Now, write a function that finds the probability that a recipe contains two specific ingredients:
#
# $$P(\text{a recipe contains ingredients } A \text{ and } B)$$
#
# This should be computed as:
#
# $$\frac{\text{number of times both ingredients were used in any recipe}}{\text{number of recipes in the dataset}}$$
#
# Exhibit that this function works by finding the probability that a recipe contains both `"feta cheese"` and `"romaine lettuce"`.

# %%
def prob_recipes_multiple(ingredients, CUISINE):
    ing_used = [True for rec in CUISINE if all(x in rec for x in ingredients)]
    probability = sum(ing_used)/len(CUISINE)
    return probability

# %%
P_FetaAndRomaine = prob_recipes_multiple(["feta cheese", "romaine lettuce"], CUISINE)

# %%
P_FetaAndRomaine
# Out:
# 0.0003017046311660884

# %% [markdown]
# __B7.__ _(5 pts)_ Next, write a function that finds the probability that a recipe contains one ingredient, given we assume    the presence of another. This is the conditional probability:
#
# $$P(\text{a recipe contains ingredient } A\mid\text{ it is a recipe that we know contains ingredient } B)$$
#
# which can be computed as a quotient from Bayes' rule:
#
# $$
# P(\text{a recipe contains ingredient } A\mid\text{it is a recipe that we know contains ingredient } B)=
# \frac{P(\text{a recipe contains ingredients } A \text{ and } B)}{P(\text{a recipe contains ingredient } B)}
# $$
#
# i.e., using the output of our previous two functions. Exhibit that this function works by finding the probability that a recipe contains `"feta cheese"`, given we know it contains `"romaine lettuce"`.

# %%
def conditional_prob_recipe(ingredient, presentIng, CUISINE):
    p_denom = prob_recipes_one(presentIng, CUISINE)
    p_nom = prob_recipes_multiple([ingredient, presentIng], CUISINE)
    probability = p_nom/p_denom
    return probability

# %%
conditional_prob_recipe("feta cheese", "romaine lettuce", CUISINE)
# Out:
# 0.044444444444444446

# %% [markdown]
# __B8.__ _(7 pts)_ Finally, write a function that finds all conditional probabilities for a given conditioning ingredient. The co-ingredients and their likelihoods should be returned in a counter.

# %%
def co_ingredients_prob(presentIng, CUISINE):
    p_denom = prob_recipes_one(presentIng, CUISINE)
    probability = Counter()
    for eachkey in [x for x in CoIngredients[presentIng].keys()]:
        probability[eachkey] = prob_recipes_multiple([eachkey, presentIng], CUISINE)/p_denom
    return probability

# %%
co_ingredients_prob("romaine lettuce", CUISINE)
# Out:
# Counter({'black olives': 0.025925925925925925,
#          'grape tomatoes': 0.05925925925925926,
#          'garlic': 0.17777777777777778,
#          'pepper': 0.15555555555555556,
#          'purple onion': 0.2740740740740741,
#          'seasoning': 0.011111111111111112,
#          'garbanzo beans': 0.018518518518518517,
#          'feta cheese crumbles': 0.07407407407407407,
#          'roasted red peppers': 0.007407407407407408,
#          'sliced mushrooms': 0.003703703703703704,
#          'hot Italian sausages': 0.003703703703703704,
#          'sprinkles': 0.003703703703703704,
#          'crumbled goat cheese': 0.003703703703703704,
#          'extra fine granulated sugar': 0.003703703703703704,
#          'sliced kalamata olives': 0.003703703703703704,
#          'goat': 0.003703703703703704,
#          'guajillo': 0.003703703703703704,
#          'black peppercorns': 0.003703703703703704,
#          'ancho chile pepper': 0.003703703703703704,
#          'clove': 0.003703703703703704,
#          'cannellini beans': 0.003703703703703704,
#          'stewed tomatoes': 0.003703703703703704,
#          'baked ham': 0.003703703703703704,
#          'cooking oil': 0.003703703703703704,
#          'snow peas': 0.003703703703703704,
#          'Greek feta': 0.003703703703703704,
#          'fresh thyme': 0.003703703703703704,
#          'sandwich wraps': 0.003703703703703704,
#          'hard salami': 0.003703703703703704,
#          'provolone cheese': 0.003703703703703704,
#          'white pepper': 0.003703703703703704,
#          'chile powder': 0.003703703703703704,
#          'chuck roast': 0.003703703703703704,
#          'brown basmati rice': 0.003703703703703704,
#          'tarragon': 0.003703703703703704,
#          'toasted baguette': 0.003703703703703704,
#          'chicken breast halves': 0.003703703703703704,
#          'frozen lemonade concentrate, thawed and undiluted': 0.003703703703703704,
#          'margarine': 0.003703703703703704,
#          'slivered almonds': 0.003703703703703704,
#          'sweet onion': 0.003703703703703704,
#          'whipping cream': 0.003703703703703704,
#          'spices': 0.003703703703703704,
#          'ground turmeric': 0.003703703703703704,
#          'yoghurt': 0.003703703703703704,
#          'saffron': 0.003703703703703704,
#          'coriander': 0.003703703703703704})

# %%
co_ingredients_prob("romaine lettuce", CUISINE)['feta cheese']
# Out:
# 0.044444444444444446

# %% [markdown]
# __B9.__ _(3 pts)_ Using your function from __B8__, find the co-ingredient likelihoods for `"feta cheese"`. Print out the top 10 most likely co-ingredients by using the `.most_common(10)` method and interpret the ingredients.
#
# When this is complete, answer the following questions in the response box below.
# - Are they related?
# - Do you interpret these as fitting into a common cuisine of recipes?

# %% [markdown]
# <font color=blue>Yes, they are somehow related. There are a lot of recipes with these ingredients together such as Greek food or some kinds of salads that have feta cheese + olive oil + etc. We can categorize certain types of recipes that are very closely related by these similar ingredients.</font>

# %%
co_ingredients_prob("feta cheese", CUISINE).most_common(10)
# Out:
# [('olive oil', 0.5186567164179104),
#  ('salt', 0.42537313432835827),
#  ('purple onion', 0.22388059701492538),
#  ('tomatoes', 0.1902985074626866),
#  ('garlic cloves', 0.1902985074626866),
#  ('dried oregano', 0.1902985074626866),
#  ('garlic', 0.1791044776119403),
#  ('pepper', 0.17537313432835822),
#  ('extra-virgin olive oil', 0.17164179104477612),
#  ('onions', 0.16417910447761194)]

# %% [markdown]
# __B10.__ _(2 pts)_ Finally, discuss the numeric values output in your execution of __B9__ in the response box below. In particular, consider how these output are probabilities, but definitely don't add up to 1! Why is this the case??
# \[Hint. think about the Sum rule and the mutual exclusivity of probabilities.\]

# %% [markdown]
# <font color=blue>The probabilities of one ingredient being the co-ingredient to all other ingredients will add up to one and this is the way to interpret these numbers instead of adding them all up. The sum of all probabilities involving for example salt will be one.</font>
